# %% [markdown]
# # Data loading

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')

# %%
X_train = train_df.drop(columns=['cardio'])
y_train = train_df['cardio']

# %%
X_test = test_df.drop(columns=['cardio'])
y_test = test_df['cardio']

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
print('m ', model.coef_)
print('c', model.intercept_)
# Out:
# m  [[ 0.33592329 -0.02851688 -0.0122117   0.10516075  0.92952541  0.11446325
#   -0.16547313 -0.24389656 -0.17231819  0.04526636 -0.37453461 -0.03379539
#    0.69791519  0.20501203  0.24101554 -0.15644239]]
# c [0.29126396]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

y_pred_proba = model.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

auc_score = roc_auc_score(y_test, y_pred_proba)

plt.figure(figsize=(7, 5))
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1])

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.grid(True, alpha=0.3)
plt.show()

# %%
model.predict()
